# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list. (unzip)
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=5c0e5e5bee03520ffc5fddd66b09ac53&units=imperial&q='

# %%
# Create an endpoint URL for a city.
city_url = query_url + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 86.67,
#   'feels_like': 84.11,
#   'temp_min': 84,
#   'temp_max': 89.01,
#   'pressure': 1014,
#   'humidity': 51},
#  'visibility': 10000,
#  'wind': {'speed': 14.99, 'deg': 150},
#  'clouds': {'all': 75},
#  'dt': 1596393521,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1596361095,
#   'sunset': 1596412955},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = query_url + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = (pd.DataFrame(city_weather["weather"]).set_index("main").iloc[0,1])

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
 
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
                          
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | thompson
# Processing Record 3 of Set 1 | cayenne
# Processing Record 4 of Set 1 | boueni
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | camana
# Processing Record 7 of Set 1 | kungurtug
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | timra
# Processing Record 11 of Set 1 | narsaq
# Processing Record 12 of Set 1 | atikokan
# Processing Record 13 of Set 1 | sitka
# Processing Record 14 of Set 1 | tawnat
# City not found. Skipping...
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | samarai
# Processing Record 18 of Set 1 | nikolskoye
# Processing Record 19 of Set 1 | upernavik
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | bambanglipuro
# Processing Record 22 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 1 | tiksi
# Processing Record 24 of Set 1 | tomatlan
# Processing Record 25 of Set 1 | dharur
# Processing Record 26 of Set 1 | bethel
# Processing Record 27 of Set 1 | sola
# Processing Record 28 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 1 | alihe
# Processing Record 30 of Set 1 | cape town
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | bengkulu
# Processing Record 33 of Set 1 | kaitangata
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | ribeira grande
# Processing Record 37 of Set 1 | roald
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | faya
# Processing Record 40 of Set 1 | butaritari
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | severo-kurilsk
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 1 | chuy
# Processing Record 46 of Set 1 | tasiilaq
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | thanh hoa
# Processing Record 49 of Set 1 | tupik
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | teguise
# Processing Record 2 of Set 2 | vila franca do campo
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | makakilo city
# Processing Record 5 of Set 2 | rundu
# Processing Record 6 of Set 2 | necochea
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | kruisfontein
# Processing Record 9 of Set 2 | castro
# Processing Record 10 of Set 2 | fortuna
# Processing Record 11 of Set 2 | new norfolk
# Processing Record 12 of Set 2 | maues
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | marawi
# Processing Record 15 of Set 2 | campbellsville
# Processing Record 16 of Set 2 | huilong
# Processing Record 17 of Set 2 | kawalu
# Processing Record 18 of Set 2 | barrow
# Processing Record 19 of Set 2 | beringovskiy
# Processing Record 20 of Set 2 | kodinsk
# Processing Record 21 of Set 2 | yenagoa
# Processing Record 22 of Set 2 | springdale
# Processing Record 23 of Set 2 | batemans bay
# Processing Record 24 of Set 2 | san patricio
# Processing Record 25 of Set 2 | hwange
# Processing Record 26 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 2 | kegayli
# City not found. Skipping...
# Processing Record 28 of Set 2 | manacapuru
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | mormugao
# Processing Record 31 of Set 2 | berlevag
# Processing Record 32 of Set 2 | karaton
# Processing Record 33 of Set 2 | mugur-aksy
# Processing Record 34 of Set 2 | vostok
# Processing Record 35 of Set 2 | atuona
# Processing Record 36 of Set 2 | port alfred
# Processing Record 37 of Set 2 | sao filipe
# Processing Record 38 of Set 2 | scottsbluff
# Processing Record 39 of Set 2 | salinopolis
# Processing Record 40 of Set 2 | trincomalee
# Processing Record 41 of Set 2 | aklavik
# Processing Record 42 of Set 2 | stornoway
# Processing Record 43 of Set 2 | port augusta
# Processing Record 44 of Set 2 | jamestown
# Processing Record 45 of Set 2 | dunedin
# Processing Record 46 of Set 2 | comodoro rivadavia
# Processing Record 47 of Set 2 | lasa
# Processing Record 48 of Set 2 | auxerre
# Processing Record 49 of Set 2 | shestakovo
# Processing Record 50 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 3 | krasnyy chikoy
# Processing Record 2 of Set 3 | makurdi
# Processing Record 3 of Set 3 | maghama
# City not found. Skipping...
# Processing Record 4 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 3 | airai
# Processing Record 6 of Set 3 | puerto ayora
# Processing Record 7 of Set 3 | sistranda
# Processing Record 8 of Set 3 | yebaishou
# Processing Record 9 of Set 3 | mattru
# Processing Record 10 of Set 3 | khatanga
# Processing Record 11 of Set 3 | lagoa
# Processing Record 12 of Set 3 | fort nelson
# Processing Record 13 of Set 3 | bathsheba
# Processing Record 14 of Set 3 | leningradskiy
# Processing Record 15 of Set 3 | banjar
# Processing Record 16 of Set 3 | pacific grove
# Processing Record 17 of Set 3 | atlantic city
# Processing Record 18 of Set 3 | lincoln
# Processing Record 19 of Set 3 | ponta do sol
# Processing Record 20 of Set 3 | clyde river
# Processing Record 21 of Set 3 | katha
# City not found. Skipping...
# Processing Record 22 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 3 | rosetown
# Processing Record 24 of Set 3 | mar del plata
# Processing Record 25 of Set 3 | yellowknife
# Processing Record 26 of Set 3 | anito
# Processing Record 27 of Set 3 | guerrero negro
# Processing Record 28 of Set 3 | arraial do cabo
# Processing Record 29 of Set 3 | paita
# Processing Record 30 of Set 3 | macae
# Processing Record 31 of Set 3 | souillac
# Processing Record 32 of Set 3 | arrifes
# Processing Record 33 of Set 3 | lompoc
# Processing Record 34 of Set 3 | pevek
# Processing Record 35 of Set 3 | erenhot
# Processing Record 36 of Set 3 | asfi
# Processing Record 37 of Set 3 | ryotsu
# Processing Record 38 of Set 3 | ribeira brava
# Processing Record 39 of Set 3 | karratha
# Processing Record 40 of Set 3 | acapulco
# Processing Record 41 of Set 3 | howard springs
# Processing Record 42 of Set 3 | tafresh
# Processing Record 43 of Set 3 | nouakchott
# Processing Record 44 of Set 3 | leshukonskoye
# Processing Record 45 of Set 3 | abu samrah
# Processing Record 46 of Set 3 | kavieng
# Processing Record 47 of Set 3 | port elizabeth
# Processing Record 48 of Set 3 | nantucket
# Processing Record 49 of Set 3 | aykhal
# Processing Record 50 of Set 3 | fort-shevchenko
# Processing Record 1 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 3 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 4 | sembakung
# Processing Record 5 of Set 4 | half moon bay
# Processing Record 6 of Set 4 | gardenstown
# Processing Record 7 of Set 4 | siguiri
# Processing Record 8 of Set 4 | progreso
# Processing Record 9 of Set 4 | luena
# Processing Record 10 of Set 4 | ancud
# Processing Record 11 of Set 4 | madanapalle
# Processing Record 12 of Set 4 | garowe
# Processing Record 13 of Set 4 | cidreira
# Processing Record 14 of Set 4 | hamilton
# Processing Record 15 of Set 4 | mastic beach
# Processing Record 16 of Set 4 | iqaluit
# Processing Record 17 of Set 4 | kantabanji
# Processing Record 18 of Set 4 | lavrentiya
# Processing Record 19 of Set 4 | cherskiy
# Processing Record 20 of Set 4 | flinders
# Processing Record 21 of Set 4 | east london
# Processing Record 22 of Set 4 | saint-philippe
# Processing Record 23 of Set 4 | praya
# Processing Record 24 of Set 4 | esperance
# Processing Record 25 of Set 4 | de-kastri
# Processing Record 26 of Set 4 | tual
# Processing Record 27 of Set 4 | virden
# Processing Record 28 of Set 4 | provideniya
# Processing Record 29 of Set 4 | hobyo
# Processing Record 30 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 4 | vrangel
# Processing Record 32 of Set 4 | bredasdorp
# Processing Record 33 of Set 4 | birin
# Processing Record 34 of Set 4 | prince george
# Processing Record 35 of Set 4 | port lincoln
# Processing Record 36 of Set 4 | usinsk
# Processing Record 37 of Set 4 | puerto escondido
# Processing Record 38 of Set 4 | kletnya
# Processing Record 39 of Set 4 | saint george
# Processing Record 40 of Set 4 | ca mau
# Processing Record 41 of Set 4 | peniche
# Processing Record 42 of Set 4 | talakan
# Processing Record 43 of Set 4 | nagykovacsi
# Processing Record 44 of Set 4 | kathu
# Processing Record 45 of Set 4 | viedma
# Processing Record 46 of Set 4 | gondal
# Processing Record 47 of Set 4 | husavik
# Processing Record 48 of Set 4 | negombo
# Processing Record 49 of Set 4 | itacoatiara
# Processing Record 50 of Set 4 | aksu
# Processing Record 1 of Set 5 | saskylakh
# Processing Record 2 of Set 5 | kulhudhuffushi
# Processing Record 3 of Set 5 | alta floresta
# Processing Record 4 of Set 5 | los llanos de aridane
# Processing Record 5 of Set 5 | harper
# Processing Record 6 of Set 5 | kadnikov
# Processing Record 7 of Set 5 | gallup
# Processing Record 8 of Set 5 | katsuura
# Processing Record 9 of Set 5 | carnarvon
# Processing Record 10 of Set 5 | chara
# Processing Record 11 of Set 5 | dengfeng
# Processing Record 12 of Set 5 | karabuk
# Processing Record 13 of Set 5 | bilibino
# Processing Record 14 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 5 | ambon
# Processing Record 16 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 17 of Set 5 | mount gambier
# Processing Record 18 of Set 5 | quelimane
# Processing Record 19 of Set 5 | constitucion
# Processing Record 20 of Set 5 | zhob
# Processing Record 21 of Set 5 | lazarev
# Processing Record 22 of Set 5 | guarapari
# Processing Record 23 of Set 5 | cuamba
# Processing Record 24 of Set 5 | tarakan
# Processing Record 25 of Set 5 | longyearbyen
# Processing Record 26 of Set 5 | carbonia
# Processing Record 27 of Set 5 | palmer
# Processing Record 28 of Set 5 | dingle
# Processing Record 29 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 31 of Set 5 | kavaratti
# Processing Record 32 of Set 5 | muros
# Processing Record 33 of Set 5 | hasaki
# Processing Record 34 of Set 5 | synya
# Processing Record 35 of Set 5 | mason city
# Processing Record 36 of Set 5 | wilmington
# Processing Record 37 of Set 5 | hanna
# Processing Record 38 of Set 5 | piacabucu
# Processing Record 39 of Set 5 | kimbe
# Processing Record 40 of Set 5 | hailey
# Processing Record 41 of Set 5 | belyy yar
# Processing Record 42 of Set 5 | nanzhang
# Processing Record 43 of Set 5 | vanimo
# Processing Record 44 of Set 5 | foix
# Processing Record 45 of Set 5 | banda aceh
# Processing Record 46 of Set 5 | tilichiki
# Processing Record 47 of Set 5 | maraa
# Processing Record 48 of Set 5 | auki
# Processing Record 49 of Set 5 | gizo
# Processing Record 50 of Set 5 | maceio
# Processing Record 1 of Set 6 | torbay
# Processing Record 2 of Set 6 | ibirama
# Processing Record 3 of Set 6 | alofi
# Processing Record 4 of Set 6 | sangar
# Processing Record 5 of Set 6 | kahului
# Processing Record 6 of Set 6 | imeni poliny osipenko
# Processing Record 7 of Set 6 | manadhoo
# Processing Record 8 of Set 6 | bestobe
# Processing Record 9 of Set 6 | taksimo
# Processing Record 10 of Set 6 | cabo san lucas
# Processing Record 11 of Set 6 | puerto pinasco
# City not found. Skipping...
# Processing Record 12 of Set 6 | goderich
# Processing Record 13 of Set 6 | hailun
# Processing Record 14 of Set 6 | perth
# Processing Record 15 of Set 6 | dukstas
# Processing Record 16 of Set 6 | latacunga
# Processing Record 17 of Set 6 | carahue
# Processing Record 18 of Set 6 | sandakan
# Processing Record 19 of Set 6 | agadez
# Processing Record 20 of Set 6 | mahebourg
# Processing Record 21 of Set 6 | santa comba
# Processing Record 22 of Set 6 | gat
# Processing Record 23 of Set 6 | allapalli
# Processing Record 24 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 6 | junqueiro
# Processing Record 26 of Set 6 | kodiak
# Processing Record 27 of Set 6 | fernie
# Processing Record 28 of Set 6 | margate
# Processing Record 29 of Set 6 | palu
# Processing Record 30 of Set 6 | kaeo
# Processing Record 31 of Set 6 | saint-denis
# Processing Record 32 of Set 6 | ahipara
# Processing Record 33 of Set 6 | dikson
# Processing Record 34 of Set 6 | santa adelia
# Processing Record 35 of Set 6 | el alto
# Processing Record 36 of Set 6 | revelstoke
# Processing Record 37 of Set 6 | lebu
# Processing Record 38 of Set 6 | zabol
# Processing Record 39 of Set 6 | axim
# Processing Record 40 of Set 6 | tambura
# Processing Record 41 of Set 6 | livingston
# Processing Record 42 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 43 of Set 6 | vestmannaeyjar
# Processing Record 44 of Set 6 | tignere
# Processing Record 45 of Set 6 | zyryanka
# Processing Record 46 of Set 6 | trairi
# Processing Record 47 of Set 6 | bambous virieux
# Processing Record 48 of Set 6 | rawlins
# Processing Record 49 of Set 6 | tura
# Processing Record 50 of Set 6 | paciran
# Processing Record 1 of Set 7 | ilulissat
# Processing Record 2 of Set 7 | lata
# Processing Record 3 of Set 7 | chicama
# Processing Record 4 of Set 7 | nechi
# Processing Record 5 of Set 7 | ayagoz
# Processing Record 6 of Set 7 | korla
# Processing Record 7 of Set 7 | norman wells
# Processing Record 8 of Set 7 | avera
# Processing Record 9 of Set 7 | pousat
# City not found. Skipping...
# Processing Record 10 of Set 7 | pleszew
# Processing Record 11 of Set 7 | rochegda
# Processing Record 12 of Set 7 | yurgamysh
# Processing Record 13 of Set 7 | mobaye
# Processing Record 14 of Set 7 | tautira
# Processing Record 15 of Set 7 | masakin
# Processing Record 16 of Set 7 | bandarbeyla
# Processing Record 17 of Set 7 | la ronge
# Processing Record 18 of Set 7 | ishigaki
# Processing Record 19 of Set 7 | chokurdakh
# Processing Record 20 of Set 7 | luanda
# Processing Record 21 of Set 7 | victoria
# Processing Record 22 of Set 7 | sao miguel do iguacu
# Processing Record 23 of Set 7 | salinas
# Processing Record 24 of Set 7 | rockland
# Processing Record 25 of Set 7 | mirzapur
# Processing Record 26 of Set 7 | raga
# Processing Record 27 of Set 7 | paratinga
# Processing Record 28 of Set 7 | lalibela
# Processing Record 29 of Set 7 | puro
# Processing Record 30 of Set 7 | jasper
# Processing Record 31 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 7 | qaqortoq
# Processing Record 33 of Set 7 | balsas
# Processing Record 34 of Set 7 | belmonte
# Processing Record 35 of Set 7 | luderitz
# Processing Record 36 of Set 7 | brae
# Processing Record 37 of Set 7 | ostrovnoy
# Processing Record 38 of Set 7 | atbasar
# Processing Record 39 of Set 7 | namibe
# Processing Record 40 of Set 7 | itaituba
# Processing Record 41 of Set 7 | bose
# Processing Record 42 of Set 7 | farkhor
# Processing Record 43 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 44 of Set 7 | vuktyl
# Processing Record 45 of Set 7 | nemuro
# Processing Record 46 of Set 7 | tessalit
# Processing Record 47 of Set 7 | male
# Processing Record 48 of Set 7 | bontang
# Processing Record 49 of Set 7 | mayumba
# Processing Record 50 of Set 7 | tuatapere
# Processing Record 1 of Set 8 | raesfeld
# Processing Record 2 of Set 8 | virginia beach
# Processing Record 3 of Set 8 | ust-kut
# Processing Record 4 of Set 8 | bratsk
# Processing Record 5 of Set 8 | dukat
# Processing Record 6 of Set 8 | manokwari
# Processing Record 7 of Set 8 | sao joao da barra
# Processing Record 8 of Set 8 | luxor
# Processing Record 9 of Set 8 | bandundu
# Processing Record 10 of Set 8 | klaksvik
# Processing Record 11 of Set 8 | nome
# Processing Record 12 of Set 8 | sorland
# Processing Record 13 of Set 8 | namatanai
# Processing Record 14 of Set 8 | wajir
# Processing Record 15 of Set 8 | erdenet
# Processing Record 16 of Set 8 | zakupne
# Processing Record 17 of Set 8 | rancho palos verdes
# Processing Record 18 of Set 8 | sorong
# Processing Record 19 of Set 8 | tommot
# Processing Record 20 of Set 8 | meulaboh
# Processing Record 21 of Set 8 | inuvik
# Processing Record 22 of Set 8 | makokou
# Processing Record 23 of Set 8 | dingzhou
# Processing Record 24 of Set 8 | sinnar
# Processing Record 25 of Set 8 | hualmay
# Processing Record 26 of Set 8 | balakhta
# Processing Record 27 of Set 8 | kuytun
# Processing Record 28 of Set 8 | sheridan
# Processing Record 29 of Set 8 | waipawa
# Processing Record 30 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 8 | nidda
# Processing Record 32 of Set 8 | faanui
# Processing Record 33 of Set 8 | nabire
# Processing Record 34 of Set 8 | cedar city
# Processing Record 35 of Set 8 | halifax
# Processing Record 36 of Set 8 | barreirinhas
# Processing Record 37 of Set 8 | te anau
# Processing Record 38 of Set 8 | zhanaozen
# Processing Record 39 of Set 8 | pochutla
# Processing Record 40 of Set 8 | broken hill
# Processing Record 41 of Set 8 | susanville
# Processing Record 42 of Set 8 | ketchikan
# Processing Record 43 of Set 8 | wajima
# Processing Record 44 of Set 8 | senanga
# Processing Record 45 of Set 8 | pisco
# Processing Record 46 of Set 8 | dongsheng
# Processing Record 47 of Set 8 | srednekolymsk
# Processing Record 48 of Set 8 | buchanan
# Processing Record 49 of Set 8 | santiago
# Processing Record 50 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 9 | ararangua
# Processing Record 3 of Set 9 | bathurst
# Processing Record 4 of Set 9 | huanren
# Processing Record 5 of Set 9 | bonfim
# Processing Record 6 of Set 9 | port moresby
# Processing Record 7 of Set 9 | kuanshan
# City not found. Skipping...
# Processing Record 8 of Set 9 | saint-joseph
# Processing Record 9 of Set 9 | tiarei
# Processing Record 10 of Set 9 | igrim
# Processing Record 11 of Set 9 | batagay-alyta
# Processing Record 12 of Set 9 | coari
# Processing Record 13 of Set 9 | eyl
# Processing Record 14 of Set 9 | tazmalt
# Processing Record 15 of Set 9 | tshela
# Processing Record 16 of Set 9 | talnakh
# Processing Record 17 of Set 9 | yulara
# Processing Record 18 of Set 9 | fairbanks
# Processing Record 19 of Set 9 | moose factory
# Processing Record 20 of Set 9 | plettenberg bay
# Processing Record 21 of Set 9 | saldanha
# Processing Record 22 of Set 9 | sindand
# City not found. Skipping...
# Processing Record 23 of Set 9 | niamtougou
# Processing Record 24 of Set 9 | florence
# Processing Record 25 of Set 9 | kollumerland
# City not found. Skipping...
# Processing Record 26 of Set 9 | college
# Processing Record 27 of Set 9 | izhma
# Processing Record 28 of Set 9 | andenes
# Processing Record 29 of Set 9 | asau
# Processing Record 30 of Set 9 | paris
# Processing Record 31 of Set 9 | codrington
# Processing Record 32 of Set 9 | miraflores
# Processing Record 33 of Set 9 | suoyarvi
# Processing Record 34 of Set 9 | duki
# Processing Record 35 of Set 9 | haines junction
# Processing Record 36 of Set 9 | kirkwall
# Processing Record 37 of Set 9 | misratah
# Processing Record 38 of Set 9 | hambantota
# Processing Record 39 of Set 9 | sfantu gheorghe
# Processing Record 40 of Set 9 | brokopondo
# Processing Record 41 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 9 | sur
# Processing Record 43 of Set 9 | pandan
# Processing Record 44 of Set 9 | hami
# Processing Record 45 of Set 9 | jasidih
# Processing Record 46 of Set 9 | oranjemund
# Processing Record 47 of Set 9 | vila velha
# Processing Record 48 of Set 9 | havoysund
# Processing Record 49 of Set 9 | novo aripuana
# Processing Record 50 of Set 9 | quatre cocos
# Processing Record 1 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 10 | ahuimanu
# Processing Record 4 of Set 10 | melfi
# Processing Record 5 of Set 10 | dneprovskaya
# Processing Record 6 of Set 10 | saint-pierre
# Processing Record 7 of Set 10 | murgab
# Processing Record 8 of Set 10 | kenai
# Processing Record 9 of Set 10 | vangaindrano
# Processing Record 10 of Set 10 | manresa
# Processing Record 11 of Set 10 | mahibadhoo
# Processing Record 12 of Set 10 | millinocket
# Processing Record 13 of Set 10 | mumbwa
# Processing Record 14 of Set 10 | kommunisticheskiy
# Processing Record 15 of Set 10 | mochalishche
# Processing Record 16 of Set 10 | varzea da palma
# Processing Record 17 of Set 10 | seoul
# Processing Record 18 of Set 10 | mayor pablo lagerenza
# Processing Record 19 of Set 10 | hokitika
# Processing Record 20 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 10 | borogontsy
# Processing Record 22 of Set 10 | cap malheureux
# Processing Record 23 of Set 10 | butler
# Processing Record 24 of Set 10 | jacksonville
# Processing Record 25 of Set 10 | coquimbo
# Processing Record 26 of Set 10 | bintulu
# Processing Record 27 of Set 10 | rocha
# Processing Record 28 of Set 10 | punta de bombon
# Processing Record 29 of Set 10 | stanesti
# Processing Record 30 of Set 10 | sompeta
# Processing Record 31 of Set 10 | qinhuangdao
# Processing Record 32 of Set 10 | isangel
# Processing Record 33 of Set 10 | rondonopolis
# Processing Record 34 of Set 10 | da nang
# Processing Record 35 of Set 10 | treinta y tres
# Processing Record 36 of Set 10 | chapais
# Processing Record 37 of Set 10 | miri
# Processing Record 38 of Set 10 | ouadda
# Processing Record 39 of Set 10 | itambacuri
# Processing Record 40 of Set 10 | nioro
# Processing Record 41 of Set 10 | richards bay
# Processing Record 42 of Set 10 | uitenhage
# Processing Record 43 of Set 10 | laguna
# Processing Record 44 of Set 10 | saint simons
# Processing Record 45 of Set 10 | pasni
# Processing Record 46 of Set 10 | yar-sale
# Processing Record 47 of Set 10 | mosquera
# Processing Record 48 of Set 10 | clarence town
# Processing Record 49 of Set 10 | popondetta
# Processing Record 50 of Set 10 | longido
# Processing Record 1 of Set 11 | ixtapa
# Processing Record 2 of Set 11 | hof
# Processing Record 3 of Set 11 | simao
# Processing Record 4 of Set 11 | daxian
# City not found. Skipping...
# Processing Record 5 of Set 11 | leiva
# Processing Record 6 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 11 | manavalakurichi
# Processing Record 8 of Set 11 | kutum
# Processing Record 9 of Set 11 | rosarito
# Processing Record 10 of Set 11 | soyo
# Processing Record 11 of Set 11 | yantal
# Processing Record 12 of Set 11 | mizdah
# Processing Record 13 of Set 11 | tiruvottiyur
# City not found. Skipping...
# Processing Record 14 of Set 11 | nouadhibou
# Processing Record 15 of Set 11 | kodinar
# Processing Record 16 of Set 11 | kamyaran
# Processing Record 17 of Set 11 | tulsipur
# Processing Record 18 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 11 | geraldton
# Processing Record 20 of Set 11 | olonets
# Processing Record 21 of Set 11 | ust-ilimsk
# Processing Record 22 of Set 11 | kirovskiy
# Processing Record 23 of Set 11 | coihaique
# Processing Record 24 of Set 11 | sao jose da coroa grande
# Processing Record 25 of Set 11 | port hardy
# Processing Record 26 of Set 11 | paramonga
# Processing Record 27 of Set 11 | vardo
# Processing Record 28 of Set 11 | nola
# Processing Record 29 of Set 11 | auchel
# Processing Record 30 of Set 11 | jiexiu
# Processing Record 31 of Set 11 | pareora
# Processing Record 32 of Set 11 | olafsvik
# Processing Record 33 of Set 11 | taybad
# Processing Record 34 of Set 11 | kholm
# Processing Record 35 of Set 11 | vao
# Processing Record 36 of Set 11 | port hedland
# Processing Record 37 of Set 11 | porto walter
# Processing Record 38 of Set 11 | baykit
# Processing Record 39 of Set 11 | noumea
# Processing Record 40 of Set 11 | lucapa
# Processing Record 41 of Set 11 | bonthe
# Processing Record 42 of Set 11 | laguna de perlas
# Processing Record 43 of Set 11 | gorahun
# Processing Record 44 of Set 11 | mayo
# Processing Record 45 of Set 11 | kaili
# Processing Record 46 of Set 11 | micheweni
# Processing Record 47 of Set 11 | neryungri
# Processing Record 48 of Set 11 | imbituba
# Processing Record 49 of Set 11 | san carlos de bariloche
# Processing Record 50 of Set 11 | qasigiannguit
# Processing Record 1 of Set 12 | lhuntshi
# City not found. Skipping...
# Processing Record 2 of Set 12 | turtkul
# City not found. Skipping...
# Processing Record 3 of Set 12 | fallon
# Processing Record 4 of Set 12 | wattegama
# Processing Record 5 of Set 12 | tevaitoa
# Processing Record 6 of Set 12 | port blair
# Processing Record 7 of Set 12 | kishtwar
# Processing Record 8 of Set 12 | townsville
# Processing Record 9 of Set 12 | aneho
# Processing Record 10 of Set 12 | poum
# Processing Record 11 of Set 12 | ilam
# Processing Record 12 of Set 12 | liku
# Processing Record 13 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 14 of Set 12 | paldiski
# Processing Record 15 of Set 12 | parrita
# Processing Record 16 of Set 12 | akcakoca
# Processing Record 17 of Set 12 | wake forest
# Processing Record 18 of Set 12 | le vauclin
# Processing Record 19 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 20 of Set 12 | awjilah
# Processing Record 21 of Set 12 | zaysan
# Processing Record 22 of Set 12 | bida
# Processing Record 23 of Set 12 | caravelas
# Processing Record 24 of Set 12 | guican
# Processing Record 25 of Set 12 | pemangkat
# Processing Record 26 of Set 12 | bara
# Processing Record 27 of Set 12 | mingguang
# Processing Record 28 of Set 12 | qingdao
# Processing Record 29 of Set 12 | bulgan
# Processing Record 30 of Set 12 | raypur
# Processing Record 31 of Set 12 | mbekenyera
# Processing Record 32 of Set 12 | ati
# Processing Record 33 of Set 12 | westport
# Processing Record 34 of Set 12 | lubyany
# Processing Record 35 of Set 12 | santa vitoria do palmar
# Processing Record 36 of Set 12 | zharkent
# Processing Record 37 of Set 12 | tadine
# Processing Record 38 of Set 12 | cockburn town
# Processing Record 39 of Set 12 | magrath
# Processing Record 40 of Set 12 | hanzhong
# Processing Record 41 of Set 12 | warrington
# Processing Record 42 of Set 12 | diego de almagro
# Processing Record 43 of Set 12 | buraydah
# Processing Record 44 of Set 12 | nenjiang
# Processing Record 45 of Set 12 | pali
# Processing Record 46 of Set 12 | mirabad
# Processing Record 47 of Set 12 | tselinnoye
# Processing Record 48 of Set 12 | vyazma
# Processing Record 49 of Set 12 | komsomolskiy
# Processing Record 50 of Set 12 | zhiryatino
# Processing Record 1 of Set 13 | mitu
# Processing Record 2 of Set 13 | douglas
# Processing Record 3 of Set 13 | kargasok
# Processing Record 4 of Set 13 | barabai
# Processing Record 5 of Set 13 | matay
# Processing Record 6 of Set 13 | andrelandia
# Processing Record 7 of Set 13 | cap-aux-meules
# Processing Record 8 of Set 13 | niimi
# Processing Record 9 of Set 13 | emirdag
# Processing Record 10 of Set 13 | sao felix do xingu
# Processing Record 11 of Set 13 | shenjiamen
# Processing Record 12 of Set 13 | surgut
# Processing Record 13 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 14 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 15 of Set 13 | kattivakkam
# Processing Record 16 of Set 13 | stokmarknes
# Processing Record 17 of Set 13 | chumikan
# Processing Record 18 of Set 13 | aden
# Processing Record 19 of Set 13 | vancouver
# Processing Record 20 of Set 13 | henties bay
# Processing Record 21 of Set 13 | salima
# Processing Record 22 of Set 13 | juneau
# Processing Record 23 of Set 13 | udachnyy
# Processing Record 24 of Set 13 | kjollefjord
# Processing Record 25 of Set 13 | pascagoula
# Processing Record 26 of Set 13 | monrovia
# Processing Record 27 of Set 13 | balagansk
# Processing Record 28 of Set 13 | esperanza
# Processing Record 29 of Set 13 | montepuez
# Processing Record 30 of Set 13 | diyarb najm
# Processing Record 31 of Set 13 | maiduguri
# Processing Record 32 of Set 13 | galveston
# Processing Record 33 of Set 13 | murray bridge
# Processing Record 34 of Set 13 | vondrozo
# Processing Record 35 of Set 13 | san quintin
# Processing Record 36 of Set 13 | shache
# Processing Record 37 of Set 13 | anadyr
# Processing Record 38 of Set 13 | orange cove
# Processing Record 39 of Set 13 | mackenzie
# Processing Record 40 of Set 13 | biak
# Processing Record 41 of Set 13 | kumano
# Processing Record 42 of Set 13 | ngunguru
# Processing Record 43 of Set 13 | gornyy
# Processing Record 44 of Set 13 | playa vicente
# Processing Record 45 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 46 of Set 13 | richmond
# Processing Record 47 of Set 13 | egvekinot
# Processing Record 48 of Set 13 | jumla
# Processing Record 49 of Set 13 | floro
# Processing Record 50 of Set 13 | moerai
# Processing Record 1 of Set 14 | mardin
# Processing Record 2 of Set 14 | trinidad
# Processing Record 3 of Set 14 | elat
# Processing Record 4 of Set 14 | presidencia roque saenz pena
# Processing Record 5 of Set 14 | lac-au-saumon
# Processing Record 6 of Set 14 | phalaborwa
# Processing Record 7 of Set 14 | nishihara
# Processing Record 8 of Set 14 | beisfjord
# Processing Record 9 of Set 14 | inzer
# Processing Record 10 of Set 14 | hirara
# Processing Record 11 of Set 14 | preobrazheniye
# Processing Record 12 of Set 14 | sarkand
# Processing Record 13 of Set 14 | ichchapuram
# Processing Record 14 of Set 14 | touros
# Processing Record 15 of Set 14 | lakatoro
# Processing Record 16 of Set 14 | mwense
# Processing Record 17 of Set 14 | ubinskoye
# Processing Record 18 of Set 14 | port macquarie
# Processing Record 19 of Set 14 | ballina
# Processing Record 20 of Set 14 | xining
# Processing Record 21 of Set 14 | moron
# Processing Record 22 of Set 14 | trat
# Processing Record 23 of Set 14 | kununurra
# Processing Record 24 of Set 14 | ishinomaki
# Processing Record 25 of Set 14 | maryville
# Processing Record 26 of Set 14 | boyuibe
# Processing Record 27 of Set 14 | rorvik
# Processing Record 28 of Set 14 | gamba
# Processing Record 29 of Set 14 | urumqi
# Processing Record 30 of Set 14 | mujiayingzi
# Processing Record 31 of Set 14 | tocache
# Processing Record 32 of Set 14 | champerico
# Processing Record 33 of Set 14 | high level
# Processing Record 34 of Set 14 | kailua
# Processing Record 35 of Set 14 | tiznit
# Processing Record 36 of Set 14 | puerto madero
# Processing Record 37 of Set 14 | quixeramobim
# Processing Record 38 of Set 14 | the valley
# Processing Record 39 of Set 14 | antofagasta
# Processing Record 40 of Set 14 | sile
# Processing Record 41 of Set 14 | spilimbergo
# Processing Record 42 of Set 14 | miramar
# Processing Record 43 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 14 | pontianak
# Processing Record 45 of Set 14 | sabha
# Processing Record 46 of Set 14 | tolmachevo
# Processing Record 47 of Set 14 | balkanabat
# Processing Record 48 of Set 14 | grand gaube
# Processing Record 49 of Set 14 | ibipeba
# Processing Record 50 of Set 14 | susangerd
# Processing Record 1 of Set 15 | gotsu
# Processing Record 2 of Set 15 | itajuba
# Processing Record 3 of Set 15 | bolshaya glushitsa
# Processing Record 4 of Set 15 | koulamoutou
# Processing Record 5 of Set 15 | solnechnyy
# Processing Record 6 of Set 15 | trapani
# Processing Record 7 of Set 15 | tranas
# Processing Record 8 of Set 15 | kasungu
# Processing Record 9 of Set 15 | nanortalik
# Processing Record 10 of Set 15 | requena
# Processing Record 11 of Set 15 | springbok
# Processing Record 12 of Set 15 | veracruz
# Processing Record 13 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 14 of Set 15 | llorente
# Processing Record 15 of Set 15 | awash
# Processing Record 16 of Set 15 | anloga
# Processing Record 17 of Set 15 | prince rupert
# Processing Record 18 of Set 15 | safaga
# Processing Record 19 of Set 15 | beruwala
# Processing Record 20 of Set 15 | praia
# Processing Record 21 of Set 15 | mackay
# Processing Record 22 of Set 15 | banikoara
# Processing Record 23 of Set 15 | yinchuan
# Processing Record 24 of Set 15 | cumberland
# Processing Record 25 of Set 15 | grand-santi
# Processing Record 26 of Set 15 | obera
# Processing Record 27 of Set 15 | concepcion de buenos aires
# Processing Record 28 of Set 15 | beeville
# Processing Record 29 of Set 15 | la sarre
# Processing Record 30 of Set 15 | den helder
# Processing Record 31 of Set 15 | oktyabrskoye
# Processing Record 32 of Set 15 | razole
# Processing Record 33 of Set 15 | grindavik
# Processing Record 34 of Set 15 | tak
# Processing Record 35 of Set 15 | lumeje
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#        City Country    Lat    Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Albany      US  42.60 -73.97      81.0        67          32       13.40
# 1  Thompson      CA  55.74 -97.86      75.2        38          20        4.70
# 2   Cayenne      GF   4.93 -52.33      84.2        70          67        5.82
# 3    Boueni      YT -12.90  45.08      75.2        78           0        8.05
# 4   Ushuaia      AR -54.80 -68.30      41.0        75          40       24.16
#
#   Current Description
# 0    scattered clouds
# 1          few clouds
# 2          light rain
# 3           clear sky
# 4    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City")
